# %% [markdown]
# <h1>LOAD ALL NECESSARY LIBRARIES</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
# nltk.download('vader_lexicon')
import nltk.corpus
import os
import sys
import json
from collections import Counter
import swifter
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import swifter
from ipywidgets import FloatProgress
from tqdm import tqdm

# %% [markdown]
# <h1>Load the json File</h1>

# %%
filename="Cell_Phones_and_Accessories"

# %%
filepath = ('Datasets/'+filename+'.json')
df_raw = pd.read_json(filepath,lines=True)

# %%
df_raw.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin   reviewerName  \
# 0        5     False  11 19, 2014  A1GG51FWU0XQYH  098949232X  Paul Williams
# 1        5     False  11 19, 2014   AVFIDS9RK38E0  098949232X    Sean Powell
# 2        5     False  11 19, 2014  A2S4AVR5SJ7KMI  098949232X      Tom Davis
# 3        5     False  11 19, 2014   AEMMMVOR9BFLI  098949232X       Kwajmeck
# 4        5     False  11 19, 2014  A2DZXMBTY7KLYP  098949232X       ScottG43
#
#                                           reviewText  \
# 0   If your into space this is the Calendar for you.
# 1                                  Awesome pictures!
# 2  Great wall art and information for space explo...
# 3  As always, it is a quality calendar full of ve...
# 4  This is a fantastic calendar. This is my third...
#
#                                  summary  unixReviewTime vote image style
# 0                             Five Stars      1416355200  NaN   NaN   NaN
# 1                             Five Stars      1416355200  NaN   NaN   NaN
# 2                             Five Stars      1416355200  NaN   NaN   NaN
# 3  I love it. I buy a new one every year      1416355200  NaN   NaN   NaN
# 4                        Great Calendar.      1416355200  NaN   NaN   NaN

# %% [markdown]
# <h1>Generate sentiment</h1>

# %%
# nltk.download('vader_lexicon')
sentiment = SentimentIntensityAnalyzer()
sid_obj = SentimentIntensityAnalyzer()
def get_compound_score(text):
    return sid_obj.polarity_scores(str(text))['compound']


df_raw['sentiment']=df_raw['reviewText'].swifter.apply(get_compound_score)

count=0
avg_rating=0
comp_rating=0
for index, row in df_raw.iterrows():
    ss = sentiment.polarity_scores(str(row['reviewText']))
    for k in sorted(ss):
        compound_score =ss['compound']
    
    avg_rating+=(compound_score+1)/2.0*5.0
    comp_rating+=(row.overall+compound_score/5.0)*(5/6)
    count+=1
    
# Calculate final average rating if count is greater than 0 to avoid division by zero
if count > 0:
    avg_rating /= count
    comp_rating /= count
# Out:
# Pandas Apply:   0%|          | 0/10063255 [00:00<?, ?it/s]

# %% [markdown]
# <h1>Save and Load the Sentiment file</h1>

# %%
#Backup all the modifications in csv file
df_raw.to_csv('output/'+filename+'.csv', index=False)
df_raw=pd.read_csv('output/'+filename+'.csv')
# Out:
# C:\Users\SUBHASHIS\AppData\Local\Temp\ipykernel_4168\2721690646.py:3: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw=pd.read_csv('output/'+filename+'.csv')

# %%
df_raw['reviewTime'] = pd.to_datetime(df_raw['unixReviewTime'], unit='s')
df_raw.head()
# Out:
#    overall  verified reviewTime      reviewerID        asin   reviewerName  \
# 0        5     False 2014-11-19  A1GG51FWU0XQYH  098949232X  Paul Williams
# 1        5     False 2014-11-19   AVFIDS9RK38E0  098949232X    Sean Powell
# 2        5     False 2014-11-19  A2S4AVR5SJ7KMI  098949232X      Tom Davis
# 3        5     False 2014-11-19   AEMMMVOR9BFLI  098949232X       Kwajmeck
# 4        5     False 2014-11-19  A2DZXMBTY7KLYP  098949232X       ScottG43
#
#                                           reviewText  \
# 0   If your into space this is the Calendar for you.
# 1                                  Awesome pictures!
# 2  Great wall art and information for space explo...
# 3  As always, it is a quality calendar full of ve...
# 4  This is a fantastic calendar. This is my third...
#
#                                  summary  unixReviewTime vote image style  \
# 0                             Five Stars      1416355200  NaN   NaN   NaN
# 1                             Five Stars      1416355200  NaN   NaN   NaN
# 2                             Five Stars      1416355200  NaN   NaN   NaN
# 3  I love it. I buy a new one every year      1416355200  NaN   NaN   NaN
# 4                        Great Calendar.      1416355200  NaN   NaN   NaN
#
#    sentiment
# 0     0.0000
# 1     0.6588
# 2     0.7184
# 3     0.8016
# 4     0.8689

# %% [markdown]
# <h1>Now group by reviewTime for 1 Week</h1>
# <p>reviewCount-> count all reviews in a week</p>
# <p>sentiment-> mean of all sentiments for diff products in a week</p>
# <p>overall->mean of all ratings in a week</p>
# <p>helpfulness->count of the number of people who liked the review</p>

# %%
df_grouped = df_raw.groupby(pd.Grouper(key='reviewTime', freq='7D')).agg(
    review_count=('reviewerID', 'count'),
    average_sentiment=('sentiment', 'mean'),
    average_rating=('overall', 'mean'),
    helpfulness=('vote','count')
).reset_index()

# %%
df_grouped=df_grouped.fillna(0)
df_grouped.set_index('reviewTime', inplace=True)
df_grouped.head()
# Out:
#             review_count  average_sentiment  average_rating  helpfulness
# reviewTime
# 1999-10-31             1             0.4966             4.0            1
# 1999-11-07             0             0.0000             0.0            0
# 1999-11-14             1             0.0000             2.0            1
# 1999-11-21             0             0.0000             0.0            0
# 1999-11-28             2             0.0926             2.5            2

# %%
df_grouped.tail(20)
# Out:
#             review_count  average_sentiment  average_rating  helpfulness
# reviewTime
# 2018-05-20         13680           0.388232        3.888158          181
# 2018-05-27         13382           0.381554        3.877373          170
# 2018-06-03         14044           0.389385        3.889134          180
# 2018-06-10         14201           0.388962        3.918175          148
# 2018-06-17         14324           0.387806        3.939263          151
# 2018-06-24         14809           0.385931        3.966980          126
# 2018-07-01         14412           0.380189        3.930752          146
# 2018-07-08         13500           0.378836        3.924815          122
# 2018-07-15         12612           0.390098        3.905725          119
# 2018-07-22         13258           0.380353        3.924951          103
# 2018-07-29         14185           0.380108        3.961579           91
# 2018-08-05         12742           0.384074        3.950008           85
# 2018-08-12         10955           0.377492        3.937837           53
# 2018-08-19          9684           0.373368        3.922656           45
# 2018-08-26          7245           0.385097        3.920635           55
# 2018-09-02          5603           0.396929        3.950384           25
# 2018-09-09          4573           0.390926        3.962825           22
# 2018-09-16          3704           0.386451        3.964363            9
# 2018-09-23          2551           0.386803        4.005488            3
# 2018-09-30           337           0.405500        4.059347            0

# %%
# See average sentiment
print(df_grouped['average_sentiment'].min(),df_grouped['average_sentiment'].max())
# Out:
# -0.9271 0.9871

# %%
min_sentiment=df_grouped['average_sentiment'].min()
max_sentiment=df_grouped['average_sentiment'].max()

# %%
df_grouped['average_sentiment']=1+(df_grouped['average_sentiment']-min_sentiment)*(5-1)/(max_sentiment-min_sentiment)

# %%
df_grouped.tail(2)
# Out:
#             review_count  average_sentiment  average_rating  helpfulness
# reviewTime
# 2018-09-23          2551           3.745592        4.005488            3
# 2018-09-30           337           3.784663        4.059347            0

# %%
max_value = df_grouped['helpfulness'].max()
min_value = df_grouped['helpfulness'].min()

df_grouped['helpfulness']=1+ (df_grouped['helpfulness']-min_value)*(4)/(max_value-min_value)

# %%
print(df_grouped['helpfulness'].min(),df_grouped['helpfulness'].max())
# Out:
# 1.0 5.0

# %%
df_grouped.tail(6)
# Out:
#             review_count  average_sentiment  average_rating  helpfulness
# reviewTime
# 2018-08-26          7245           3.742027        3.920635     1.051139
# 2018-09-02          5603           3.766751        3.950384     1.023245
# 2018-09-09          4573           3.754207        3.962825     1.020456
# 2018-09-16          3704           3.744857        3.964363     1.008368
# 2018-09-23          2551           3.745592        4.005488     1.002789
# 2018-09-30           337           3.784663        4.059347     1.000000

# %%
df_grouped['mixture']=df_grouped['helpfulness']*df_grouped['average_sentiment']*df_grouped['average_rating']

# %%
max_value = df_grouped['mixture'].max()
min_value = df_grouped['mixture'].min()

print(min_value,max_value)
# Out:
# 0.0 76.41879951703565

# %%
df_grouped['mixture']=1+ (df_grouped['mixture']-min_value)*(4)/(max_value-min_value)

# %%
df_grouped.tail()
# Out:
#             review_count  average_sentiment  average_rating  helpfulness  \
# reviewTime
# 2018-09-02          5603           3.766751        3.950384     1.023245
# 2018-09-09          4573           3.754207        3.962825     1.020456
# 2018-09-16          3704           3.744857        3.964363     1.008368
# 2018-09-23          2551           3.745592        4.005488     1.002789
# 2018-09-30           337           3.784663        4.059347     1.000000
#
#              mixture
# reviewTime
# 2018-09-02  1.796977
# 2018-09-09  1.794652
# 2018-09-16  1.783588
# 2018-09-23  1.787491
# 2018-09-30  1.804161

# %%
print(df_grouped['mixture'].max(),df_grouped['mixture'].min())
# Out:
# 5.0 1.0

# %%
max_value = df_grouped['review_count'].max()
min_value = df_grouped['review_count'].min()

print(min_value,max_value)
df_grouped['review_count']=1+ (df_grouped['review_count']-min_value)*(4)/(max_value-min_value)
# Out:
# 0 63468

# %% [markdown]
# <h1>Now training the models</h1>

# %%
#  split train/valid/test
n = len(df_grouped)
train_end = int(n * 0.7)
val_end = n - int(n * 0.1)
test_end = n

# %%
print("Total dataset length=",n);
print("Datasets to be trained upon:",train_end);
print("Datasets to be validated upon:",val_end-train_end);
print("Datasets to be tested upon:",test_end-val_end);
# Out:
# Total dataset length= 988
# Datasets to be trained upon: 691
# Datasets to be validated upon: 199
# Datasets to be tested upon: 98

# %%
seq_len=16
pred_len=60
batch_size=60

df_grouped_bak=df_grouped

df_grouped_bak['review_count'] = np.log(df_grouped_bak['review_count']+1)

log_min = df_grouped_bak['review_count'].min()
log_max = df_grouped_bak['review_count'].max()


df_grouped_bak=df_grouped_bak/10

# %%
df_grouped_bak['review_count']
# Out:
# reviewTime
# 1999-10-31    0.069318
# 1999-11-07    0.069315
# 1999-11-14    0.069318
# 1999-11-21    0.069315
# 1999-11-28    0.069321
#                 ...
# 2018-09-02    0.085574
# 2018-09-09    0.082777
# 2018-09-16    0.080354
# 2018-09-23    0.077047
# 2018-09-30    0.070371
# Name: review_count, Length: 988, dtype: float64

# %%
# df_grouped_bak['review_count']

# %%
sum(df_grouped_bak.mixture<0)
# Out:
# 0

# %%
train_df = df_grouped_bak[:train_end]
val_df = df_grouped_bak[train_end - seq_len: val_end]
test_df = df_grouped_bak[val_end - seq_len: test_end]

# %%
def _split_window(data,target_slice=slice(0,None)):
    inputs = data[:, : seq_len, :]
    labels = data[:, seq_len :, target_slice]
    inputs.set_shape([None, seq_len, None])
    labels.set_shape([None, pred_len, None])
    return inputs, labels

def _make_dataset(data, shuffle=True, targets=None):
    data = np.array(data, dtype=np.float32)
    ds = tf.keras.utils.timeseries_dataset_from_array(
        data=data,
        targets=targets,
        sequence_length=(seq_len + pred_len),
        sequence_stride=5,
        shuffle=shuffle,
        batch_size=batch_size,
    )
    ds = ds.map(_split_window)
    return ds

def get_train(self, shuffle=True):
    return self._make_dataset(self.train_df, shuffle=shuffle)

# %%
import tensorflow as tf
train_data  =   _make_dataset(train_df, shuffle=False)
val_data    =   _make_dataset(val_df, shuffle=False)
test_data   =   _make_dataset(test_df, shuffle=False)

# %%
from tensorflow.keras import layers

def res_block(inputs, ff_dim):

  norm = layers.LayerNormalization

  # Time mixing
  x = norm(axis=[-2, -1])(inputs)
  x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Channel, Input Length]
  x = layers.Dense(x.shape[-1], activation='relu')(x)
  x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Input Length, Channel]
  x = layers.Dropout(0.6)(x)
  res = x + inputs

  # Feature mixing
  x = norm(axis=[-2, -1])(res)
  x = layers.Dense(ff_dim, activation='relu')(x)  # [Batch, Input Length, FF_Dim]
  x = layers.Dropout(0.6)(x)
  x = layers.Dense(inputs.shape[-1])(x)  # [Batch, Input Length, Channel]
  x = layers.Dropout(0.6)(x)
  return (x + res ) #* (avg_rating/5.0) * (comp_rating/5.0)

# %%
def build_model(
    input_shape,
    pred_len,
    n_block,
    ff_dim,
    target_slice,
):

  inputs = tf.keras.Input(shape=input_shape)
  x = inputs  # [Batch, Input Length, Channel]
  for _ in range(n_block):
    x = res_block(x, ff_dim)

  if target_slice:
    x = x[:, :, target_slice]

  # Temporal projection
  x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Channel, Input Length]
  x = layers.Dense(pred_len)(x)  # [Batch, Channel, Output Length]
  outputs = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Output Length, Channel])

  return tf.keras.Model(inputs, outputs)

# %%
n_feature = train_df.shape[-1]
model = build_model(
    input_shape=(seq_len, n_feature),
    pred_len=pred_len,
    n_block=16,
    ff_dim=64,
    target_slice=slice(0,None)
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# tf.keras.utils.set_random_seed(7)
tf.keras.utils.set_random_seed(7)

initial_learning_rate = 0.1
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=24,
    decay_rate=0.97,
    staircase=True
)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(optimizer, loss='mse', metrics=['mse'])
checkpoint_callback = ModelCheckpoint(
    'best_model.h5',           
    monitor='val_mse',        
    save_best_only=True,       # Save only the best model (lowest val_loss)
    mode='min',                
    verbose=1,
)

# %%
history = model.fit(
    train_data,
    epochs= 1000,
    validation_data=test_data,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/1000
# 2/3 [===================>..........] - ETA: 0s - loss: 141.4040 - mse: 141.4040
# Epoch 1: val_mse improved from inf to 56.72766, saving model to best_model.h5
# 3/3 [==============================] - 13s 1s/step - loss: 136.9635 - mse: 136.9635 - val_loss: 56.7277 - val_mse: 56.7277
# Epoch 2/1000
# 2/3 [===================>..........] - ETA: 0s - loss: 70.5234 - mse: 70.5234
# Epoch 2: val_mse improved from 56.72766 to 8.91199, saving model to best_model.h5
# 3/3 [==============================] - 0s 211ms/step - loss: 68.7650 - mse: 68.7650 - val_loss: 8.9120 - val_mse: 8.9120
# Epoch 3/1000
# 2/3 [===================>..........] - ETA: 0s - loss: 11.8074 - mse: 11.8074
# Epoch 3: val_mse did not improve from 8.91199
# 3/3 [==============================] - 0s 77ms/step - loss: 11.7833 - mse: 11.7833 - val_loss: 9.9169 - val_mse: 9.9169
# Epoch 4/1000
# 3/3 [==============================] - ETA: 0s - loss: 15.1616 - mse: 15.1616
# Epoch 4: val_mse improved from 8.91199 to 4.42439, saving model to best_model.h5
# 3/3 [==============================] - 0s 208ms/step - loss: 15.1616 - mse: 15.1616 - val_loss: 4.4244 - val_mse: 4.4244
# Epoch 5/1000
# 3/3 [==============================] - ETA: 0s - loss: 8.0272 - mse: 8.0272
# Epoch 5: val_mse improved from 4.42439 to 3.81398, saving model to best_model.h5
# 3/3 [==============================] - 0s 207ms/step - loss: 8.0272 - mse: 8.0272 - val_loss: 3.8140 - val_mse: 3.8140
# Epoch 6/1000
# 3/3 [==============================] - ETA: 0s - loss: 8.1403 - mse: 8.1403
# Epoch 6: val_mse did not improve from 3.81398
# 3/3 [==============================] - 0s 74ms/step - loss: 8.1403 - mse: 8.1403 - val_loss: 6.2890 - val_mse: 6.2890
# Epoch 7/1000
# 3/3 [==============================] - ETA: 0s - loss: 9.5858 - mse: 9.5858
# Epoch 7: val_mse improved from 3.81398 to 1.83927, saving model to best_model.h5
# 3/3 [==============================] - 0s 205ms/step - loss: 9.5858 - mse: 9.5858 - val_loss: 1.8393 - val_mse: 1.8393
# Epoch 8/1000
# 3/3 [==============================] - ETA: 0s - loss: 6.8423 - mse: 6.8423
# Epoch 8: val_mse improved from 1.83927 to 1.65437, saving model to best_model.h5
# 3/3 [==============================] - 0s 205ms/step - loss: 6.8423 - mse: 6.8423 - val_loss: 1.6544 - val_mse: 1.6544
# Epoch 9/1000
# 3/3 [==============================] - ETA: 0s - loss: 6.8735 - mse: 6.8735
# Epoch 9: val_mse did not improve from 1.65437
# 3/3 [==============================] - 0s 77ms/step - loss: 6.8735 - mse: 6.8735 - val_loss: 1.7471 - val_mse: 1.7471
# Epoch 10/1000
# 3/3 [==============================] - ETA: 0s - loss: 4.6634 - mse: 4.6634
# Epoch 10: val_mse improved from 1.65437 to 0.48673, saving model to best_model.h5
# 3/3 [==============================] - 0s 205ms/step - loss: 4.6634 - mse: 4.6634 - val_loss: 0.4867 - val_mse: 0.4867
# Epoch 11/1000
# 3/3 [==============================] - ETA: 0s - loss: 2.8318 - mse: 2.8318
# Epoch 11: val_mse did not improve from 0.48673
# 3/3 [==============================] - 0s 73ms/step - loss: 2.8318 - mse: 2.8318 - val_loss: 0.6082 - val_mse: 0.6082
# Epoch 12/1000
# 3/3 [==============================] - ETA: 0s - loss: 2.3637 - mse: 2.3637
# Epoch 12: val_mse did not improve from 0.48673
# 3/3 [==============================] - 0s 72ms/step - loss: 2.3637 - mse: 2.3637 - val_loss: 1.2129 - val_mse: 1.2129
# Epoch 13/1000
# 3/3 [==============================] - ETA: 0s - loss: 2.0625 - mse: 2.0625
# Epoch 13: val_mse improved from 0.48673 to 0.26777, saving model to best_model.h5
# 3/3 [==============================] - 0s 206ms/step - loss: 2.0625 - mse: 2.0625 - val_loss: 0.2678 - val_mse: 0.2678
# Epoch 14/1000
# 3/3 [==============================] - ETA: 0s - loss: 1.6963 - mse: 1.6963
# Epoch 14: val_mse improved from 0.26777 to 0.18360, saving model to best_model.h5
# 3/3 [==============================] - 0s 208ms/step - loss: 1.6963 - mse: 1.6963 - val_loss: 0.1836 - val_mse: 0.1836
# Epoch 15/1000
# 3/3 [==============================] - ETA: 0s - loss: 1.0808 - mse: 1.0808
# Epoch 15: val_mse did not improve from 0.18360
# 3/3 [==============================] - 0s 72ms/step - loss: 1.0808 - mse: 1.0808 - val_loss: 0.2864 - val_mse: 0.2864
# Epoch 16/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.8467 - mse: 0.8467
# Epoch 16: val_mse did not improve from 0.18360
# 3/3 [==============================] - 0s 73ms/step - loss: 0.8467 - mse: 0.8467 - val_loss: 0.1950 - val_mse: 0.1950
# Epoch 17/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.5476 - mse: 0.5476
# Epoch 17: val_mse improved from 0.18360 to 0.17768, saving model to best_model.h5
# 3/3 [==============================] - 0s 201ms/step - loss: 0.5476 - mse: 0.5476 - val_loss: 0.1777 - val_mse: 0.1777
# Epoch 18/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.6694 - mse: 0.6694
# Epoch 18: val_mse improved from 0.17768 to 0.17228, saving model to best_model.h5
# 3/3 [==============================] - 0s 203ms/step - loss: 0.6694 - mse: 0.6694 - val_loss: 0.1723 - val_mse: 0.1723
# Epoch 19/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.4083 - mse: 0.4083
# Epoch 19: val_mse did not improve from 0.17228
# 3/3 [==============================] - 0s 71ms/step - loss: 0.4083 - mse: 0.4083 - val_loss: 0.2745 - val_mse: 0.2745
# Epoch 20/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3530 - mse: 0.3530
# Epoch 20: val_mse improved from 0.17228 to 0.16786, saving model to best_model.h5
# 3/3 [==============================] - 0s 207ms/step - loss: 0.3530 - mse: 0.3530 - val_loss: 0.1679 - val_mse: 0.1679
# Epoch 21/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.2678 - mse: 0.2678
# Epoch 21: val_mse improved from 0.16786 to 0.07545, saving model to best_model.h5
# 3/3 [==============================] - 0s 209ms/step - loss: 0.2678 - mse: 0.2678 - val_loss: 0.0755 - val_mse: 0.0755
# Epoch 22/1000
# 2/3 [===================>..........] - ETA: 0s - loss: 0.2017 - mse: 0.2017
# Epoch 22: val_mse did not improve from 0.07545
# 3/3 [==============================] - 0s 79ms/step - loss: 0.2004 - mse: 0.2004 - val_loss: 0.0853 - val_mse: 0.0853
# Epoch 23/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.2289 - mse: 0.2289
# Epoch 23: val_mse improved from 0.07545 to 0.06594, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.0659 - val_mse: 0.0659
# Epoch 24/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1634 - mse: 0.1634
# Epoch 24: val_mse improved from 0.06594 to 0.06092, saving model to best_model.h5
# 3/3 [==============================] - 0s 203ms/step - loss: 0.1634 - mse: 0.1634 - val_loss: 0.0609 - val_mse: 0.0609
# Epoch 25/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1430 - mse: 0.1430
# Epoch 25: val_mse improved from 0.06092 to 0.04807, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.1430 - mse: 0.1430 - val_loss: 0.0481 - val_mse: 0.0481
# Epoch 26/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1188 - mse: 0.1188
# Epoch 26: val_mse improved from 0.04807 to 0.04458, saving model to best_model.h5
# 3/3 [==============================] - 0s 205ms/step - loss: 0.1188 - mse: 0.1188 - val_loss: 0.0446 - val_mse: 0.0446
# Epoch 27/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0998 - mse: 0.0998
# Epoch 27: val_mse did not improve from 0.04458
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0998 - mse: 0.0998 - val_loss: 0.0481 - val_mse: 0.0481
# Epoch 28/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1032 - mse: 0.1032
# Epoch 28: val_mse did not improve from 0.04458
# 3/3 [==============================] - 0s 73ms/step - loss: 0.1032 - mse: 0.1032 - val_loss: 0.0506 - val_mse: 0.0506
# Epoch 29/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0780 - mse: 0.0780
# Epoch 29: val_mse did not improve from 0.04458
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0780 - mse: 0.0780 - val_loss: 0.0511 - val_mse: 0.0511
# Epoch 30/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0819 - mse: 0.0819
# Epoch 30: val_mse improved from 0.04458 to 0.04346, saving model to best_model.h5
# 3/3 [==============================] - 0s 205ms/step - loss: 0.0819 - mse: 0.0819 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 31/1000
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0736 - mse: 0.0736
# Epoch 31: val_mse improved from 0.04346 to 0.03440, saving model to best_model.h5
# 3/3 [==============================] - 0s 213ms/step - loss: 0.0734 - mse: 0.0734 - val_loss: 0.0344 - val_mse: 0.0344
# Epoch 32/1000
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0621 - mse: 0.0621
# Epoch 32: val_mse improved from 0.03440 to 0.03269, saving model to best_model.h5
# 3/3 [==============================] - 0s 215ms/step - loss: 0.0632 - mse: 0.0632 - val_loss: 0.0327 - val_mse: 0.0327
# Epoch 33/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0581 - mse: 0.0581
# Epoch 33: val_mse did not improve from 0.03269
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0581 - mse: 0.0581 - val_loss: 0.0339 - val_mse: 0.0339
# Epoch 34/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0589 - mse: 0.0589
# Epoch 34: val_mse improved from 0.03269 to 0.03252, saving model to best_model.h5
# 3/3 [==============================] - 0s 206ms/step - loss: 0.0589 - mse: 0.0589 - val_loss: 0.0325 - val_mse: 0.0325
# Epoch 35/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0575 - mse: 0.0575
# Epoch 35: val_mse improved from 0.03252 to 0.02590, saving model to best_model.h5
# 3/3 [==============================] - 0s 206ms/step - loss: 0.0575 - mse: 0.0575 - val_loss: 0.0259 - val_mse: 0.0259
# Epoch 36/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0558 - mse: 0.0558
# Epoch 36: val_mse improved from 0.02590 to 0.02220, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.0558 - mse: 0.0558 - val_loss: 0.0222 - val_mse: 0.0222
# Epoch 37/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0511 - mse: 0.0511
# Epoch 37: val_mse did not improve from 0.02220
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0511 - mse: 0.0511 - val_loss: 0.0235 - val_mse: 0.0235
# Epoch 38/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0474 - mse: 0.0474
# Epoch 38: val_mse did not improve from 0.02220
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0474 - mse: 0.0474 - val_loss: 0.0225 - val_mse: 0.0225
# Epoch 39/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0453 - mse: 0.0453
# Epoch 39: val_mse improved from 0.02220 to 0.02026, saving model to best_model.h5
# 3/3 [==============================] - 0s 205ms/step - loss: 0.0453 - mse: 0.0453 - val_loss: 0.0203 - val_mse: 0.0203
# Epoch 40/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0451 - mse: 0.0451
# Epoch 40: val_mse improved from 0.02026 to 0.01959, saving model to best_model.h5
# 3/3 [==============================] - 0s 206ms/step - loss: 0.0451 - mse: 0.0451 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 41/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0424 - mse: 0.0424
# Epoch 41: val_mse improved from 0.01959 to 0.01919, saving model to best_model.h5
# 3/3 [==============================] - 0s 205ms/step - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 42/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0410 - mse: 0.0410
# Epoch 42: val_mse did not improve from 0.01919
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 43/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0412 - mse: 0.0412
# Epoch 43: val_mse improved from 0.01919 to 0.01870, saving model to best_model.h5
# 3/3 [==============================] - 0s 208ms/step - loss: 0.0412 - mse: 0.0412 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 44/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0436 - mse: 0.0436
# Epoch 44: val_mse improved from 0.01870 to 0.01692, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 45/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0357 - mse: 0.0357
# Epoch 45: val_mse improved from 0.01692 to 0.01640, saving model to best_model.h5
# 3/3 [==============================] - 0s 201ms/step - loss: 0.0357 - mse: 0.0357 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 46/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0359 - mse: 0.0359
# Epoch 46: val_mse did not improve from 0.01640
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0359 - mse: 0.0359 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 47/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0340 - mse: 0.0340
# Epoch 47: val_mse improved from 0.01640 to 0.01597, saving model to best_model.h5
# 3/3 [==============================] - 0s 205ms/step - loss: 0.0340 - mse: 0.0340 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 48/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0338 - mse: 0.0338
# Epoch 48: val_mse improved from 0.01597 to 0.01433, saving model to best_model.h5
# 3/3 [==============================] - 0s 210ms/step - loss: 0.0338 - mse: 0.0338 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 49/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0319 - mse: 0.0319
# Epoch 49: val_mse improved from 0.01433 to 0.01329, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.0319 - mse: 0.0319 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 50/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0327 - mse: 0.0327
# Epoch 50: val_mse improved from 0.01329 to 0.01250, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.0327 - mse: 0.0327 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 51/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0317 - mse: 0.0317
# Epoch 51: val_mse did not improve from 0.01250
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0317 - mse: 0.0317 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 52/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0324 - mse: 0.0324
# Epoch 52: val_mse did not improve from 0.01250
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0324 - mse: 0.0324 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 53/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0315 - mse: 0.0315
# Epoch 53: val_mse did not improve from 0.01250
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0315 - mse: 0.0315 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 54/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0302 - mse: 0.0302
# Epoch 54: val_mse improved from 0.01250 to 0.01210, saving model to best_model.h5
# 3/3 [==============================] - 0s 218ms/step - loss: 0.0302 - mse: 0.0302 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 55/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0298 - mse: 0.0298
# Epoch 55: val_mse improved from 0.01210 to 0.01144, saving model to best_model.h5
# 3/3 [==============================] - 0s 216ms/step - loss: 0.0298 - mse: 0.0298 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 56/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0302 - mse: 0.0302
# Epoch 56: val_mse did not improve from 0.01144
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0302 - mse: 0.0302 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 57/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0271 - mse: 0.0271
# Epoch 57: val_mse did not improve from 0.01144
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0271 - mse: 0.0271 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 58/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0259 - mse: 0.0259
# Epoch 58: val_mse improved from 0.01144 to 0.01113, saving model to best_model.h5
# 3/3 [==============================] - 1s 265ms/step - loss: 0.0259 - mse: 0.0259 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 59/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0273 - mse: 0.0273
# Epoch 59: val_mse did not improve from 0.01113
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 60/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0265 - mse: 0.0265
# Epoch 60: val_mse improved from 0.01113 to 0.01084, saving model to best_model.h5
# 3/3 [==============================] - 1s 315ms/step - loss: 0.0265 - mse: 0.0265 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 61/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0245 - mse: 0.0245
# Epoch 61: val_mse improved from 0.01084 to 0.01059, saving model to best_model.h5
# 3/3 [==============================] - 1s 252ms/step - loss: 0.0245 - mse: 0.0245 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 62/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0265 - mse: 0.0265
# Epoch 62: val_mse improved from 0.01059 to 0.00969, saving model to best_model.h5
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0265 - mse: 0.0265 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 63/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0241 - mse: 0.0241
# Epoch 63: val_mse improved from 0.00969 to 0.00912, saving model to best_model.h5
# 3/3 [==============================] - 1s 230ms/step - loss: 0.0241 - mse: 0.0241 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 64/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0224 - mse: 0.0224
# Epoch 64: val_mse did not improve from 0.00912
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0224 - mse: 0.0224 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 65/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0230 - mse: 0.0230
# Epoch 65: val_mse did not improve from 0.00912
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0230 - mse: 0.0230 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 66/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0209 - mse: 0.0209
# Epoch 66: val_mse did not improve from 0.00912
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 67/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0213 - mse: 0.0213
# Epoch 67: val_mse improved from 0.00912 to 0.00896, saving model to best_model.h5
# 3/3 [==============================] - 1s 246ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 68/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0223 - mse: 0.0223
# Epoch 68: val_mse did not improve from 0.00896
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0223 - mse: 0.0223 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 69/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0209 - mse: 0.0209
# Epoch 69: val_mse did not improve from 0.00896
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 70/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0219 - mse: 0.0219
# Epoch 70: val_mse did not improve from 0.00896
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 71/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0215 - mse: 0.0215
# Epoch 71: val_mse improved from 0.00896 to 0.00873, saving model to best_model.h5
# 3/3 [==============================] - 1s 254ms/step - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 72/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0197
# Epoch 72: val_mse improved from 0.00873 to 0.00844, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 73/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0199
# Epoch 73: val_mse did not improve from 0.00844
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0199 - mse: 0.0199 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 74/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0184 - mse: 0.0184
# Epoch 74: val_mse did not improve from 0.00844
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 75/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0196 - mse: 0.0196
# Epoch 75: val_mse did not improve from 0.00844
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 76/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0189 - mse: 0.0189
# Epoch 76: val_mse improved from 0.00844 to 0.00794, saving model to best_model.h5
# 3/3 [==============================] - 0s 203ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 77/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0188 - mse: 0.0188
# Epoch 77: val_mse improved from 0.00794 to 0.00781, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 78/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0176 - mse: 0.0176
# Epoch 78: val_mse improved from 0.00781 to 0.00752, saving model to best_model.h5
# 3/3 [==============================] - 0s 200ms/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 79/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0173 - mse: 0.0173
# Epoch 79: val_mse did not improve from 0.00752
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 80/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0165 - mse: 0.0165
# Epoch 80: val_mse did not improve from 0.00752
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 81/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0165 - mse: 0.0165
# Epoch 81: val_mse did not improve from 0.00752
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 82/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0152 - mse: 0.0152
# Epoch 82: val_mse improved from 0.00752 to 0.00746, saving model to best_model.h5
# 3/3 [==============================] - 0s 213ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 83/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0160 - mse: 0.0160
# Epoch 83: val_mse improved from 0.00746 to 0.00707, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 84/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0159 - mse: 0.0159
# Epoch 84: val_mse did not improve from 0.00707
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 85/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0160 - mse: 0.0160
# Epoch 85: val_mse did not improve from 0.00707
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 86/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0152 - mse: 0.0152
# Epoch 86: val_mse did not improve from 0.00707
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 87/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0157 - mse: 0.0157
# Epoch 87: val_mse did not improve from 0.00707
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 88/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0142 - mse: 0.0142
# Epoch 88: val_mse did not improve from 0.00707
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 89/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0158 - mse: 0.0158
# Epoch 89: val_mse improved from 0.00707 to 0.00592, saving model to best_model.h5
# 3/3 [==============================] - 0s 202ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 90/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0147 - mse: 0.0147
# Epoch 90: val_mse improved from 0.00592 to 0.00547, saving model to best_model.h5
# 3/3 [==============================] - 0s 202ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 91/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0147 - mse: 0.0147
# Epoch 91: val_mse did not improve from 0.00547
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 92/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0136 - mse: 0.0136
# Epoch 92: val_mse did not improve from 0.00547
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 93/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0146 - mse: 0.0146
# Epoch 93: val_mse did not improve from 0.00547
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 94/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0148 - mse: 0.0148
# Epoch 94: val_mse did not improve from 0.00547
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 95/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0136 - mse: 0.0136
# Epoch 95: val_mse did not improve from 0.00547
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 96/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0148 - mse: 0.0148
# Epoch 96: val_mse did not improve from 0.00547
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 97/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0124 - mse: 0.0124
# Epoch 97: val_mse did not improve from 0.00547
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 98/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0126 - mse: 0.0126
# Epoch 98: val_mse did not improve from 0.00547
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 99/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0129 - mse: 0.0129
# Epoch 99: val_mse improved from 0.00547 to 0.00546, saving model to best_model.h5
# 3/3 [==============================] - 0s 200ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 100/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0133 - mse: 0.0133
# Epoch 100: val_mse did not improve from 0.00546
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 101/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0123 - mse: 0.0123
# Epoch 101: val_mse did not improve from 0.00546
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 102/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0119 - mse: 0.0119
# Epoch 102: val_mse did not improve from 0.00546
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 103/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0118 - mse: 0.0118
# Epoch 103: val_mse did not improve from 0.00546
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 104/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0121 - mse: 0.0121
# Epoch 104: val_mse improved from 0.00546 to 0.00540, saving model to best_model.h5
# 3/3 [==============================] - 0s 201ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 105/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0117 - mse: 0.0117
# Epoch 105: val_mse improved from 0.00540 to 0.00531, saving model to best_model.h5
# 3/3 [==============================] - 0s 202ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 106/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0109 - mse: 0.0109
# Epoch 106: val_mse did not improve from 0.00531
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 107/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0114 - mse: 0.0114
# Epoch 107: val_mse did not improve from 0.00531
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 108/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0102 - mse: 0.0102
# Epoch 108: val_mse did not improve from 0.00531
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 109/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0116 - mse: 0.0116
# Epoch 109: val_mse did not improve from 0.00531
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 110/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0107 - mse: 0.0107
# Epoch 110: val_mse improved from 0.00531 to 0.00502, saving model to best_model.h5
# 3/3 [==============================] - 0s 201ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 111/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0108 - mse: 0.0108
# Epoch 111: val_mse improved from 0.00502 to 0.00481, saving model to best_model.h5
# 3/3 [==============================] - 0s 201ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 112/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0100 - mse: 0.0100
# Epoch 112: val_mse did not improve from 0.00481
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 113/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0112 - mse: 0.0112
# Epoch 113: val_mse did not improve from 0.00481
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 114/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0101 - mse: 0.0101
# Epoch 114: val_mse did not improve from 0.00481
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 115/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0103 - mse: 0.0103
# Epoch 115: val_mse improved from 0.00481 to 0.00473, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 116/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0099 - mse: 0.0099
# Epoch 116: val_mse did not improve from 0.00473
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 117/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0105 - mse: 0.0105
# Epoch 117: val_mse did not improve from 0.00473
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 118/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0095 - mse: 0.0095
# Epoch 118: val_mse did not improve from 0.00473
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 119/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0095 - mse: 0.0095
# Epoch 119: val_mse did not improve from 0.00473
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 120/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0097 - mse: 0.0097
# Epoch 120: val_mse did not improve from 0.00473
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 121/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0097 - mse: 0.0097
# Epoch 121: val_mse improved from 0.00473 to 0.00444, saving model to best_model.h5
# 3/3 [==============================] - 0s 203ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 122/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0101 - mse: 0.0101
# Epoch 122: val_mse improved from 0.00444 to 0.00439, saving model to best_model.h5
# 3/3 [==============================] - 0s 202ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 123/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0099 - mse: 0.0099
# Epoch 123: val_mse did not improve from 0.00439
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 124/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0089 - mse: 0.0089
# Epoch 124: val_mse did not improve from 0.00439
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 125/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0098 - mse: 0.0098
# Epoch 125: val_mse did not improve from 0.00439
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 126/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0092 - mse: 0.0092
# Epoch 126: val_mse improved from 0.00439 to 0.00434, saving model to best_model.h5
# 3/3 [==============================] - 0s 201ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 127/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0088 - mse: 0.0088
# Epoch 127: val_mse improved from 0.00434 to 0.00432, saving model to best_model.h5
# 3/3 [==============================] - 0s 201ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 128/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0086 - mse: 0.0086
# Epoch 128: val_mse did not improve from 0.00432
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 129/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0087 - mse: 0.0087
# Epoch 129: val_mse did not improve from 0.00432
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 130/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0092 - mse: 0.0092
# Epoch 130: val_mse did not improve from 0.00432
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 131/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0086 - mse: 0.0086
# Epoch 131: val_mse did not improve from 0.00432
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 132/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0094 - mse: 0.0094
# Epoch 132: val_mse did not improve from 0.00432
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 133/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0086 - mse: 0.0086
# Epoch 133: val_mse did not improve from 0.00432
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 134/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0088 - mse: 0.0088
# Epoch 134: val_mse did not improve from 0.00432
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 135/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0086 - mse: 0.0086
# Epoch 135: val_mse did not improve from 0.00432
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 136/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0083 - mse: 0.0083
# Epoch 136: val_mse improved from 0.00432 to 0.00426, saving model to best_model.h5
# 3/3 [==============================] - 0s 201ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 137/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0086 - mse: 0.0086
# Epoch 137: val_mse improved from 0.00426 to 0.00423, saving model to best_model.h5
# 3/3 [==============================] - 0s 203ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 138/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0080 - mse: 0.0080
# Epoch 138: val_mse did not improve from 0.00423
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 139/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0088 - mse: 0.0088
# Epoch 139: val_mse improved from 0.00423 to 0.00416, saving model to best_model.h5
# 3/3 [==============================] - 0s 203ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 140/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0081 - mse: 0.0081
# Epoch 140: val_mse improved from 0.00416 to 0.00414, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 141/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0084 - mse: 0.0084
# Epoch 141: val_mse did not improve from 0.00414
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 142/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0083 - mse: 0.0083
# Epoch 142: val_mse did not improve from 0.00414
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 143/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0092 - mse: 0.0092
# Epoch 143: val_mse improved from 0.00414 to 0.00409, saving model to best_model.h5
# 3/3 [==============================] - 0s 203ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 144/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0078 - mse: 0.0078
# Epoch 144: val_mse did not improve from 0.00409
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 145/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0076 - mse: 0.0076
# Epoch 145: val_mse did not improve from 0.00409
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 146/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0083 - mse: 0.0083
# Epoch 146: val_mse improved from 0.00409 to 0.00378, saving model to best_model.h5
# 3/3 [==============================] - 0s 204ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 147/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0074 - mse: 0.0074
# Epoch 147: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 148/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0075 - mse: 0.0075
# Epoch 148: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 149/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0079 - mse: 0.0079
# Epoch 149: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 150/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0074 - mse: 0.0074
# Epoch 150: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 151/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0067 - mse: 0.0067
# Epoch 151: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 152/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0073 - mse: 0.0073
# Epoch 152: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 153/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0069 - mse: 0.0069
# Epoch 153: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 154/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0074 - mse: 0.0074
# Epoch 154: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 155/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0075 - mse: 0.0075
# Epoch 155: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 156/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0089 - mse: 0.0089
# Epoch 156: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 157/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0072 - mse: 0.0072
# Epoch 157: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 158/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0070 - mse: 0.0070
# Epoch 158: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 159/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0073 - mse: 0.0073
# Epoch 159: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 160/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0066 - mse: 0.0066
# Epoch 160: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 161/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0071 - mse: 0.0071
# Epoch 161: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 162/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0067 - mse: 0.0067
# Epoch 162: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 163/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0068 - mse: 0.0068
# Epoch 163: val_mse did not improve from 0.00378
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 164/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0065 - mse: 0.0065
# Epoch 164: val_mse improved from 0.00378 to 0.00372, saving model to best_model.h5
# 3/3 [==============================] - 0s 207ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 165/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0070 - mse: 0.0070
# Epoch 165: val_mse did not improve from 0.00372
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 166/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0065 - mse: 0.0065
# Epoch 166: val_mse did not improve from 0.00372
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 167/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0068 - mse: 0.0068
# Epoch 167: val_mse did not improve from 0.00372
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 168/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0070 - mse: 0.0070
# Epoch 168: val_mse did not improve from 0.00372
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 169/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0077 - mse: 0.0077
# Epoch 169: val_mse improved from 0.00372 to 0.00353, saving model to best_model.h5
# 3/3 [==============================] - 0s 205ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 170/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0071 - mse: 0.0071
# Epoch 170: val_mse did not improve from 0.00353
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 171/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0069 - mse: 0.0069
# Epoch 171: val_mse did not improve from 0.00353
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 172/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0076 - mse: 0.0076
# Epoch 172: val_mse did not improve from 0.00353
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 173/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0066 - mse: 0.0066
# Epoch 173: val_mse did not improve from 0.00353
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 174/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0073 - mse: 0.0073
# Epoch 174: val_mse did not improve from 0.00353
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 175/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0071 - mse: 0.0071
# Epoch 175: val_mse did not improve from 0.00353
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 176/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0063 - mse: 0.0063
# Epoch 176: val_mse did not improve from 0.00353
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 177/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0065 - mse: 0.0065
# Epoch 177: val_mse did not improve from 0.00353
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 178/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0069 - mse: 0.0069
# Epoch 178: val_mse did not improve from 0.00353
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0037 - val_mse: 0.0037
# ...
# Epoch 939/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 939: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 940/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 940: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 941/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 941: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 942/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - mse: 0.0027
# Epoch 942: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 943/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 943: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 944/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 944: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 945/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 945: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 946/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 946: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 947/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 947: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 948/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 948: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 949/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 949: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 950/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 950: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 951/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 951: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 952/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 952: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 953/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 953: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 954/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0033 - mse: 0.0033
# Epoch 954: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 955/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0032 - mse: 0.0032
# Epoch 955: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 956/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 956: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 957/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 957: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 958/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0032 - mse: 0.0032
# Epoch 958: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 959/1000
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0032 - mse: 0.0032
# Epoch 959: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 960/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 960: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 961/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 961: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 962/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 962: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 963/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 963: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 964/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 964: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 965/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 965: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 966/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 966: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 967/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 967: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 968/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 968: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 969/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 969: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 970/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 970: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 971/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 971: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 972/1000
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 972: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 973/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 973: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 974/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 974: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 975/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 975: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 976/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 976: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 977/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0035 - mse: 0.0035
# Epoch 977: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 978/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 978: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 979/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 979: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 980/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 980: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 981/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 981: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 982/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - mse: 0.0027
# Epoch 982: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 983/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 983: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 984/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 984: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 985/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 985: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 986/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 986: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 987/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 987: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 988/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 988: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 989/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 989: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 990/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 990: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 991/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 991: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 992/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 992: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 993/1000
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 993: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 994/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 994: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 995/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 995: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 996/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 996: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 997/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 997: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 998/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 998: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 999/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 999: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 1000/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 1000: val_mse did not improve from 0.00326
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0038 - val_mse: 0.0038

# %%
from tensorflow.keras.models import load_model
model = load_model('best_model.h5')
predictions = model.predict(test_data)

scaled_preds = predictions[-1,:,:]

scaled_preds.shape

cols = ['review_count','average_sentiment','average_rating','helpfulness','mixture']
scaled_preds_df = pd.DataFrame(scaled_preds)
scaled_preds_df.columns = cols
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
df_grouped
# Out:
#             review_count  average_sentiment  average_rating  helpfulness  \
# reviewTime
# 1999-10-31      0.693179           3.975029        4.000000     1.000930
# 1999-11-07      0.693147           2.937311        0.000000     1.000000
# 1999-11-14      0.693179           2.937311        2.000000     1.000930
# 1999-11-21      0.693147           2.937311        0.000000     1.000000
# 1999-11-28      0.693210           3.130812        2.500000     1.001860
# ...                  ...                ...             ...          ...
# 2018-09-02      0.855743           3.766751        3.950384     1.023245
# 2018-09-09      0.827769           3.754207        3.962825     1.020456
# 2018-09-16      0.803543           3.744857        3.964363     1.008368
# 2018-09-23      0.770466           3.745592        4.005488     1.002789
# 2018-09-30      0.703711           3.784663        4.059347     1.000000
#
#              mixture
# reviewTime
# 1999-10-31  1.833036
# 1999-11-07  1.000000
# 1999-11-14  1.307782
# 1999-11-21  1.000000
# 1999-11-28  1.410453
# ...              ...
# 2018-09-02  1.796977
# 2018-09-09  1.794652
# 2018-09-16  1.783588
# 2018-09-23  1.787491
# 2018-09-30  1.804161
#
# [988 rows x 5 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(12,8))

for i, ax in enumerate(axes.flatten()[0:4]):
    col = cols[i+1]
    print(col)
    ax.plot(df_grouped.index[-pred_len:], df_grouped_bak[col][-pred_len:], label = 'Actual Value', color='blue')
    ax.plot(df_grouped.index[-pred_len:], scaled_preds_df[col], label='TSMixer', ls='--', color='red')
    
    ax.legend(loc='best')
    ax.set_xlabel('Time steps')
    ax.set_ylabel('Value')
    ax.set_ylim(-2, 2) 
    ax.set_title(col)
    
plt.tight_layout()
fig.autofmt_xdate()

plt.savefig('RESULT_'+filename+'.jpg')
# Out:
# average_sentiment
# average_rating
# helpfulness
# mixture

# %% [markdown]
# <h1>MSE</h1>

# %%
for column in cols[4:5]:
    mse = ((df_grouped_bak[column][-pred_len:].values - scaled_preds_df[column].values) ** 2).mean()
    print('MSE('+column+')='+str(round(mse*100,5))+'%')
# Out:
# MSE(mixture)=0.21839%

# %% [markdown]
# <h1>MSLE</h1>

# %%
for column in cols[4:5]:
    msle = ((np.log1p(df_grouped_bak[column][-pred_len:].values) - np.log1p(scaled_preds_df[column].values)) ** 2).mean()
    print('MSLE('+column+')='+str(round(msle*100,5))+'%')
# Out:
# MSLE(mixture)=0.14624%

# %% [markdown]
# <h1>MAPE</h1>

# %%
for column in cols[4:5]:
    mape= (abs((df_grouped_bak[column][-pred_len:].values - scaled_preds_df[column].values) / df_grouped_bak[column][-pred_len:].values)).mean() * 100
    print('MAPE('+column+')='+str(round(mape,5))+'%')
# Out:
# MAPE(mixture)=19.52497%
